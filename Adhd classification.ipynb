# %%
pip install mne
# Out:
# Collecting mne
#   Downloading mne-1.7.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.4)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from mne) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (24.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.1)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from mne) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.2.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.2.2)
# Installing collected packages: mne
# Successfully installed mne-1.7.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py
import os
import glob
import mne
import numpy as np
import scipy.io as sio
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import glob2 as glob

# %%
# Specify the channel types
ch_types = ['eeg'] * 19
ch_names = ['EEG1', 'EEG2', 'EEG3', 'EEG4','EEG5','EEG6','EEG7','EEG8','EEG9','EEG10','EEG11','EEG12','EEG13','EEG14','EEG15','EEG16','EEG17','EEG18','EEG19']

# Specify the output directory for .fif files
output_directory_path = '/content/ADHD_fif'

# Specify the directory containing your .mat EEG files
directory_path1 = '/content/drive/MyDrive/ADHD_part1'
directory_path2 = '/content/drive/MyDrive/ADHD_part2'

# Get a list of all .mat files in the directory
mat_files1 = glob.glob(os.path.join(directory_path1, '*.mat'))
mat_files2 = glob.glob(os.path.join(directory_path2, '*.mat'))
mat_files=mat_files1 + mat_files2

# Loop through each file
for mat_file in mat_files:
    mat_contents = sio.loadmat(mat_file)
    electrode_data = np.array(mat_contents[os.path.splitext(os.path.basename(mat_file))[0]])
    data = [i for i in electrode_data.T]  # Transpose the data


    # Create info and RawArray
    raw_info = mne.create_info(ch_names=ch_names, sfreq=128, ch_types=ch_types)
    raw = mne.io.RawArray(data, info=raw_info)

    # Save the RawArray to a .fif file in the output directory
    output_filename = os.path.splitext(os.path.basename(mat_file))[0] + '.fif'
    output_filepath = os.path.join(output_directory_path, output_filename)
    raw.save(output_filepath, overwrite=True)
    print(f"Saved {output_filepath}")



print("Processing complete!")
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=24241
#     Range : 0 ... 24240 =      0.000 ...   189.375 secs
# Ready.
# Writing /content/ADHD_fif/v173.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v173.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Closing /content/ADHD_fif/v173.fif
# [done]
# Saved /content/ADHD_fif/v173.fif
# Creating RawArray with float64 data, n_channels=19, n_times=43252
#     Range : 0 ... 43251 =      0.000 ...   337.898 secs
# Ready.
# Writing /content/ADHD_fif/v15p.fif
# Closing /content/ADHD_fif/v15p.fif
# [done]
# Saved /content/ADHD_fif/v15p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v15p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17562
#     Range : 0 ... 17561 =      0.000 ...   137.195 secs
# Ready.
# Writing /content/ADHD_fif/v14p.fif
# Closing /content/ADHD_fif/v14p.fif
# [done]
# Saved /content/ADHD_fif/v14p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v14p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17604
#     Range : 0 ... 17603 =      0.000 ...   137.523 secs
# Ready.
# Writing /content/ADHD_fif/v12p.fif
# Closing /content/ADHD_fif/v12p.fif
# [done]
# Saved /content/ADHD_fif/v12p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v12p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14304
#     Range : 0 ... 14303 =      0.000 ...   111.742 secs
# Ready.
# Writing /content/ADHD_fif/v10p.fif
# Closing /content/ADHD_fif/v10p.fif
# [done]
# Saved /content/ADHD_fif/v10p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v10p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=25003
#     Range : 0 ... 25002 =      0.000 ...   195.328 secs
# Ready.
# Writing /content/ADHD_fif/v18p.fif
# Closing /content/ADHD_fif/v18p.fif
# [done]
# Saved /content/ADHD_fif/v18p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v18p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12258
#     Range : 0 ... 12257 =      0.000 ...    95.758 secs
# Ready.
# Writing /content/ADHD_fif/v1p.fif
# Closing /content/ADHD_fif/v1p.fif
# [done]
# Saved /content/ADHD_fif/v1p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v1p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=23063
#     Range : 0 ... 23062 =      0.000 ...   180.172 secs
# Ready.
# Writing /content/ADHD_fif/v19p.fif
# Closing /content/ADHD_fif/v19p.fif
# [done]
# Saved /content/ADHD_fif/v19p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v19p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=35328
#     Range : 0 ... 35327 =      0.000 ...   275.992 secs
# Ready.
# Writing /content/ADHD_fif/v20p.fif
# Closing /content/ADHD_fif/v20p.fif
# [done]
# Saved /content/ADHD_fif/v20p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v20p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=9894
#     Range : 0 ... 9893 =      0.000 ...    77.289 secs
# Ready.
# Writing /content/ADHD_fif/v25p.fif
# Closing /content/ADHD_fif/v25p.fif
# [done]
# Saved /content/ADHD_fif/v25p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v25p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16574
#     Range : 0 ... 16573 =      0.000 ...   129.477 secs
# Ready.
# Writing /content/ADHD_fif/v21p.fif
# Closing /content/ADHD_fif/v21p.fif
# [done]
# Saved /content/ADHD_fif/v21p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v21p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16385
#     Range : 0 ... 16384 =      0.000 ...   128.000 secs
# Ready.
# Writing /content/ADHD_fif/v24p.fif
# Closing /content/ADHD_fif/v24p.fif
# [done]
# Saved /content/ADHD_fif/v24p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v24p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12100
#     Range : 0 ... 12099 =      0.000 ...    94.523 secs
# Ready.
# Writing /content/ADHD_fif/v22p.fif
# Closing /content/ADHD_fif/v22p.fif
# [done]
# Saved /content/ADHD_fif/v22p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v22p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18049
#     Range : 0 ... 18048 =      0.000 ...   141.000 secs
# Ready.
# Writing /content/ADHD_fif/v32p.fif
# Closing /content/ADHD_fif/v32p.fif
# [done]
# Saved /content/ADHD_fif/v32p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v32p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=29217
#     Range : 0 ... 29216 =      0.000 ...   228.250 secs
# Ready.
# Writing /content/ADHD_fif/v33p.fif
# Closing /content/ADHD_fif/v33p.fif
# [done]
# Saved /content/ADHD_fif/v33p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v33p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=21663
#     Range : 0 ... 21662 =      0.000 ...   169.234 secs
# Ready.
# Writing /content/ADHD_fif/v30p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v30p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Closing /content/ADHD_fif/v30p.fif
# [done]
# Saved /content/ADHD_fif/v30p.fif
# Creating RawArray with float64 data, n_channels=19, n_times=15305
#     Range : 0 ... 15304 =      0.000 ...   119.562 secs
# Ready.
# Writing /content/ADHD_fif/v35p.fif
# Closing /content/ADHD_fif/v35p.fif
# [done]
# Saved /content/ADHD_fif/v35p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v35p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=9286
#     Range : 0 ... 9285 =      0.000 ...    72.539 secs
# Ready.
# Writing /content/ADHD_fif/v37p.fif
# Closing /content/ADHD_fif/v37p.fif
# [done]
# Saved /content/ADHD_fif/v37p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v37p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=28880
#     Range : 0 ... 28879 =      0.000 ...   225.617 secs
# Ready.
# Writing /content/ADHD_fif/v27p.fif
# Closing /content/ADHD_fif/v27p.fif
# [done]
# Saved /content/ADHD_fif/v27p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v27p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=27612
#     Range : 0 ... 27611 =      0.000 ...   215.711 secs
# Ready.
# Writing /content/ADHD_fif/v28p.fif
# Closing /content/ADHD_fif/v28p.fif
# [done]
# Saved /content/ADHD_fif/v28p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v28p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19555
#     Range : 0 ... 19554 =      0.000 ...   152.766 secs
# Ready.
# Writing /content/ADHD_fif/v34p.fif
# Closing /content/ADHD_fif/v34p.fif
# [done]
# Saved /content/ADHD_fif/v34p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v34p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17401
#     Range : 0 ... 17400 =      0.000 ...   135.938 secs
# Ready.
# Writing /content/ADHD_fif/v36p.fif
# Closing /content/ADHD_fif/v36p.fif
# [done]
# Saved /content/ADHD_fif/v36p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v36p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=24193
#     Range : 0 ... 24192 =      0.000 ...   189.000 secs
# Ready.
# Writing /content/ADHD_fif/v29p.fif
# Closing /content/ADHD_fif/v29p.fif
# [done]
# Saved /content/ADHD_fif/v29p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v29p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=11679
#     Range : 0 ... 11678 =      0.000 ...    91.234 secs
# Ready.
# Writing /content/ADHD_fif/v31p.fif
# Closing /content/ADHD_fif/v31p.fif
# [done]
# Saved /content/ADHD_fif/v31p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v31p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17561
#     Range : 0 ... 17560 =      0.000 ...   137.188 secs
# Ready.
# Writing /content/ADHD_fif/v6p.fif
# Closing /content/ADHD_fif/v6p.fif
# [done]
# Saved /content/ADHD_fif/v6p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v6p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=24695
#     Range : 0 ... 24694 =      0.000 ...   192.922 secs
# Ready.
# Writing /content/ADHD_fif/v38p.fif
# Closing /content/ADHD_fif/v38p.fif
# [done]
# Saved /content/ADHD_fif/v38p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v38p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=33570
#     Range : 0 ... 33569 =      0.000 ...   262.258 secs
# Ready.
# Writing /content/ADHD_fif/v3p.fif
# Closing /content/ADHD_fif/v3p.fif
# [done]
# Saved /content/ADHD_fif/v3p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v3p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18177
#     Range : 0 ... 18176 =      0.000 ...   142.000 secs
# Ready.
# Writing /content/ADHD_fif/v39p.fif
# Closing /content/ADHD_fif/v39p.fif
# [done]
# Saved /content/ADHD_fif/v39p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v39p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=20097
#     Range : 0 ... 20096 =      0.000 ...   157.000 secs
# Ready.
# Writing /content/ADHD_fif/v40p.fif
# Closing /content/ADHD_fif/v40p.fif
# [done]
# Saved /content/ADHD_fif/v40p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v40p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15776
#     Range : 0 ... 15775 =      0.000 ...   123.242 secs
# Ready.
# Writing /content/ADHD_fif/v8p.fif
# Closing /content/ADHD_fif/v8p.fif
# [done]
# Saved /content/ADHD_fif/v8p.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v8p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12353
#     Range : 0 ... 12352 =      0.000 ...    96.500 secs
# Ready.
# Writing /content/ADHD_fif/v213.fif
# Closing /content/ADHD_fif/v213.fif
# [done]
# Saved /content/ADHD_fif/v213.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v213.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16697
#     Range : 0 ... 16696 =      0.000 ...   130.438 secs
# Ready.
# Writing /content/ADHD_fif/v177.fif
# Closing /content/ADHD_fif/v177.fif
# [done]
# Saved /content/ADHD_fif/v177.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v177.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=20456
#     Range : 0 ... 20455 =      0.000 ...   159.805 secs
# Ready.
# Writing /content/ADHD_fif/v204.fif
# Closing /content/ADHD_fif/v204.fif
# [done]
# Saved /content/ADHD_fif/v204.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v204.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=20173
#     Range : 0 ... 20172 =      0.000 ...   157.594 secs
# Ready.
# Writing /content/ADHD_fif/v206.fif
# Closing /content/ADHD_fif/v206.fif
# [done]
# Saved /content/ADHD_fif/v206.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v206.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=21372
#     Range : 0 ... 21371 =      0.000 ...   166.961 secs
# Ready.
# Writing /content/ADHD_fif/v215.fif
# Closing /content/ADHD_fif/v215.fif
# [done]
# Saved /content/ADHD_fif/v215.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v215.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12739
#     Range : 0 ... 12738 =      0.000 ...    99.516 secs
# Ready.
# Writing /content/ADHD_fif/v200.fif
# Closing /content/ADHD_fif/v200.fif
# [done]
# Saved /content/ADHD_fif/v200.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v200.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15465
#     Range : 0 ... 15464 =      0.000 ...   120.812 secs
# Ready.
# Writing /content/ADHD_fif/v190.fif
# Closing /content/ADHD_fif/v190.fif
# [done]
# Saved /content/ADHD_fif/v190.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v190.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13395
#     Range : 0 ... 13394 =      0.000 ...   104.641 secs
# Ready.
# Writing /content/ADHD_fif/v196.fif
# Closing /content/ADHD_fif/v196.fif
# [done]
# Saved /content/ADHD_fif/v196.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v196.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12673
#     Range : 0 ... 12672 =      0.000 ...    99.000 secs
# Ready.
# Writing /content/ADHD_fif/v179.fif
# Closing /content/ADHD_fif/v179.fif
# [done]
# Saved /content/ADHD_fif/v179.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v179.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=27157
#     Range : 0 ... 27156 =      0.000 ...   212.156 secs
# Ready.
# Writing /content/ADHD_fif/v219.fif
# Closing /content/ADHD_fif/v219.fif
# [done]
# Saved /content/ADHD_fif/v219.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v219.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=10668
#     Range : 0 ... 10667 =      0.000 ...    83.336 secs
# Ready.
# Writing /content/ADHD_fif/v181.fif
# Closing /content/ADHD_fif/v181.fif
# [done]
# Saved /content/ADHD_fif/v181.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v181.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18591
#     Range : 0 ... 18590 =      0.000 ...   145.234 secs
# Ready.
# Writing /content/ADHD_fif/v183.fif
# Closing /content/ADHD_fif/v183.fif
# [done]
# Saved /content/ADHD_fif/v183.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v183.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=30273
#     Range : 0 ... 30272 =      0.000 ...   236.500 secs
# Ready.
# Writing /content/ADHD_fif/v209.fif
# Closing /content/ADHD_fif/v209.fif
# [done]
# Saved /content/ADHD_fif/v209.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v209.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19621
#     Range : 0 ... 19620 =      0.000 ...   153.281 secs
# Ready.
# Writing /content/ADHD_fif/v198.fif
# Closing /content/ADHD_fif/v198.fif
# [done]
# Saved /content/ADHD_fif/v198.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v198.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=9852
#     Range : 0 ... 9851 =      0.000 ...    76.961 secs
# Ready.
# Writing /content/ADHD_fif/v238.fif
# Closing /content/ADHD_fif/v238.fif
# [done]
# Saved /content/ADHD_fif/v238.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v238.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=34191
#     Range : 0 ... 34190 =      0.000 ...   267.109 secs
# Ready.
# Writing /content/ADHD_fif/v234.fif
# Closing /content/ADHD_fif/v234.fif
# [done]
# Saved /content/ADHD_fif/v234.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v234.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13853
#     Range : 0 ... 13852 =      0.000 ...   108.219 secs
# Ready.
# Writing /content/ADHD_fif/v250.fif
# Closing /content/ADHD_fif/v250.fif
# [done]
# Saved /content/ADHD_fif/v250.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v250.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=21307
#     Range : 0 ... 21306 =      0.000 ...   166.453 secs
# Ready.
# Writing /content/ADHD_fif/v246.fif
# Closing /content/ADHD_fif/v246.fif
# [done]
# Saved /content/ADHD_fif/v246.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v246.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13502
#     Range : 0 ... 13501 =      0.000 ...   105.477 secs
# Ready.
# Writing /content/ADHD_fif/v236.fif
# Closing /content/ADHD_fif/v236.fif
# [done]
# Saved /content/ADHD_fif/v236.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v236.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18657
#     Range : 0 ... 18656 =      0.000 ...   145.750 secs
# Ready.
# Writing /content/ADHD_fif/v263.fif
# Closing /content/ADHD_fif/v263.fif
# [done]
# Saved /content/ADHD_fif/v263.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v263.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17323
#     Range : 0 ... 17322 =      0.000 ...   135.328 secs
# Ready.
# Writing /content/ADHD_fif/v274.fif
# Closing /content/ADHD_fif/v274.fif
# [done]
# Saved /content/ADHD_fif/v274.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v274.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18389
#     Range : 0 ... 18388 =      0.000 ...   143.656 secs
# Ready.
# Writing /content/ADHD_fif/v265.fif
# Closing /content/ADHD_fif/v265.fif
# [done]
# Saved /content/ADHD_fif/v265.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v265.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19713
#     Range : 0 ... 19712 =      0.000 ...   154.000 secs
# Ready.
# Writing /content/ADHD_fif/v231.fif
# Closing /content/ADHD_fif/v231.fif
# [done]
# Saved /content/ADHD_fif/v231.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v231.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=28080
#     Range : 0 ... 28079 =      0.000 ...   219.367 secs
# Ready.
# Writing /content/ADHD_fif/v227.fif
# Closing /content/ADHD_fif/v227.fif
# [done]
# Saved /content/ADHD_fif/v227.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v227.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=39030
#     Range : 0 ... 39029 =      0.000 ...   304.914 secs
# Ready.
# Writing /content/ADHD_fif/v244.fif
# Closing /content/ADHD_fif/v244.fif
# [done]
# Saved /content/ADHD_fif/v244.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v244.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=23681
#     Range : 0 ... 23680 =      0.000 ...   185.000 secs
# Ready.
# Writing /content/ADHD_fif/v270.fif
# Closing /content/ADHD_fif/v270.fif
# [done]
# Saved /content/ADHD_fif/v270.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v270.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=10477
#     Range : 0 ... 10476 =      0.000 ...    81.844 secs
# Ready.
# Writing /content/ADHD_fif/v254.fif
# Closing /content/ADHD_fif/v254.fif
# [done]
# Saved /content/ADHD_fif/v254.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v254.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=11465
#     Range : 0 ... 11464 =      0.000 ...    89.562 secs
# Ready.
# Writing /content/ADHD_fif/v286.fif
# Closing /content/ADHD_fif/v286.fif
# [done]
# Saved /content/ADHD_fif/v286.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v286.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15383
#     Range : 0 ... 15382 =      0.000 ...   120.172 secs
# Ready.
# Writing /content/ADHD_fif/v284.fif
# Closing /content/ADHD_fif/v284.fif
# [done]
# Saved /content/ADHD_fif/v284.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v284.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=20134
#     Range : 0 ... 20133 =      0.000 ...   157.289 secs
# Ready.
# Writing /content/ADHD_fif/v279.fif
# Closing /content/ADHD_fif/v279.fif
# [done]
# Saved /content/ADHD_fif/v279.fif
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v279.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=20115
#     Range : 0 ... 20114 =      0.000 ...   157.141 secs
# Ready.
# Writing /content/ADHD_fif/v288.fif
# Closing /content/ADHD_fif/v288.fif
# [done]
# Saved /content/ADHD_fif/v288.fif
# Processing complete!
# <ipython-input-6-cfe63bff8ea3>:31: RuntimeWarning: This filename (/content/ADHD_fif/v288.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)

# %%
raw = mne.io.read_raw_fif(r'/content/ADHD_fif/v10p.fif' ,preload=True)
# Out:
# Opening raw data file /content/ADHD_fif/v10p.fif...
# Isotrak not found
#     Range : 0 ... 14303 =      0.000 ...   111.742 secs
# Ready.
# Reading 0 ... 14303  =      0.000 ...   111.742 secs...
# <ipython-input-7-bd5043952041>:1: RuntimeWarning: This filename (/content/ADHD_fif/v10p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(r'/content/ADHD_fif/v10p.fif' ,preload=True)

# %%
raw.compute_psd(fmax=64).plot(picks="data", exclude="bads")
# Out:
# Effective window size : 16.000 (s)
# Plotting power spectral density (dB=True).
# <ipython-input-8-b540e28d23d3>:1: FutureWarning: The value of `amplitude='auto'` will be removed in MNE 1.8.0, and the new default will be `amplitude=False`.
#   raw.compute_psd(fmax=64).plot(picks="data", exclude="bads")
# <ipython-input-8-b540e28d23d3>:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.compute_psd(fmax=64).plot(picks="data", exclude="bads")
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
# Specify the output directory for .fif files
output_directory_path = '/content/Control_fif'

# Specify the directory containing your .mat EEG files
directory_path1 = '/content/drive/MyDrive/Control_part1'
directory_path2 = '/content/drive/MyDrive/Control_part2'

# Get a list of all .mat files in the directory
mat_files1 = glob.glob(os.path.join(directory_path1, '*.mat'))
mat_files2 = glob.glob(os.path.join(directory_path2, '*.mat'))
mat_files=mat_files1 + mat_files2

# Loop through each file
for mat_file in mat_files:
    mat_contents = sio.loadmat(mat_file)
    electrode_data = np.array(mat_contents[os.path.splitext(os.path.basename(mat_file))[0]])
    data = [i for i in electrode_data.T]  # Transpose the data


    # Create info and RawArray
    raw_info = mne.create_info(ch_names=ch_names, sfreq=128, ch_types=ch_types)
    raw = mne.io.RawArray(data, info=raw_info)

    # Save the RawArray to a .fif file in the output directory
    output_filename = os.path.splitext(os.path.basename(mat_file))[0] + '.fif'
    output_filepath = os.path.join(output_directory_path, output_filename)
    raw.save(output_filepath, overwrite=True)
    print(f"Saved {output_filepath}")



print("Processing complete!")
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=16549
#     Range : 0 ... 16548 =      0.000 ...   129.281 secs
# Ready.
# Writing /content/Control_fif/v110.fif
# Closing /content/Control_fif/v110.fif
# [done]
# Saved /content/Control_fif/v110.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v110.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16044
#     Range : 0 ... 16043 =      0.000 ...   125.336 secs
# Ready.
# Writing /content/Control_fif/v109.fif
# Closing /content/Control_fif/v109.fif
# [done]
# Saved /content/Control_fif/v109.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v109.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19794
#     Range : 0 ... 19793 =      0.000 ...   154.633 secs
# Ready.
# Writing /content/Control_fif/v107.fif
# Closing /content/Control_fif/v107.fif
# [done]
# Saved /content/Control_fif/v107.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v107.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19026
#     Range : 0 ... 19025 =      0.000 ...   148.633 secs
# Ready.
# Writing /content/Control_fif/v108.fif
# Closing /content/Control_fif/v108.fif
# [done]
# Saved /content/Control_fif/v108.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v108.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15574
#     Range : 0 ... 15573 =      0.000 ...   121.664 secs
# Ready.
# Writing /content/Control_fif/v113.fif
# Closing /content/Control_fif/v113.fif
# [done]
# Saved /content/Control_fif/v113.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v113.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15310
#     Range : 0 ... 15309 =      0.000 ...   119.602 secs
# Ready.
# Writing /content/Control_fif/v111.fif
# Closing /content/Control_fif/v111.fif
# [done]
# Saved /content/Control_fif/v111.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v111.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13304
#     Range : 0 ... 13303 =      0.000 ...   103.930 secs
# Ready.
# Writing /content/Control_fif/v114.fif
# Closing /content/Control_fif/v114.fif
# [done]
# Saved /content/Control_fif/v114.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v114.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15651
#     Range : 0 ... 15650 =      0.000 ...   122.266 secs
# Ready.
# Writing /content/Control_fif/v115.fif
# Closing /content/Control_fif/v115.fif
# [done]
# Saved /content/Control_fif/v115.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v115.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15943
#     Range : 0 ... 15942 =      0.000 ...   124.547 secs
# Ready.
# Writing /content/Control_fif/v112.fif
# Closing /content/Control_fif/v112.fif
# [done]
# Saved /content/Control_fif/v112.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v112.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19301
#     Range : 0 ... 19300 =      0.000 ...   150.781 secs
# Ready.
# Writing /content/Control_fif/v116.fif
# Closing /content/Control_fif/v116.fif
# [done]
# Saved /content/Control_fif/v116.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v116.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=11393
#     Range : 0 ... 11392 =      0.000 ...    89.000 secs
# Ready.
# Writing /content/Control_fif/v44p.fif
# Closing /content/Control_fif/v44p.fif
# [done]
# Saved /content/Control_fif/v44p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v44p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12750
#     Range : 0 ... 12749 =      0.000 ...    99.602 secs
# Ready.
# Writing /content/Control_fif/v43p.fif
# Closing /content/Control_fif/v43p.fif
# [done]
# Saved /content/Control_fif/v43p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v43p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12500
#     Range : 0 ... 12499 =      0.000 ...    97.648 secs
# Ready.
# Writing /content/Control_fif/v41p.fif
# Closing /content/Control_fif/v41p.fif
# [done]
# Saved /content/Control_fif/v41p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v41p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16704
#     Range : 0 ... 16703 =      0.000 ...   130.492 secs
# Ready.
# Writing /content/Control_fif/v42p.fif
# Closing /content/Control_fif/v42p.fif
# [done]
# Saved /content/Control_fif/v42p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v42p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16513
#     Range : 0 ... 16512 =      0.000 ...   129.000 secs
# Ready.
# Writing /content/Control_fif/v59p.fif
# Closing /content/Control_fif/v59p.fif
# [done]
# Saved /content/Control_fif/v59p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v59p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16769
#     Range : 0 ... 16768 =      0.000 ...   131.000 secs
# Ready.
# Writing /content/Control_fif/v49p.fif
# Closing /content/Control_fif/v49p.fif
# [done]
# Saved /content/Control_fif/v49p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v49p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14692
#     Range : 0 ... 14691 =      0.000 ...   114.773 secs
# Ready.
# Writing /content/Control_fif/v57p.fif
# Closing /content/Control_fif/v57p.fif
# [done]
# Saved /content/Control_fif/v57p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v57p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=7983
#     Range : 0 ... 7982 =      0.000 ...    62.359 secs
# Ready.
# Writing /content/Control_fif/v51p.fif
# Closing /content/Control_fif/v51p.fif
# [done]
# Saved /content/Control_fif/v51p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v51p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13918
#     Range : 0 ... 13917 =      0.000 ...   108.727 secs
# Ready.
# Writing /content/Control_fif/v58p.fif
# Closing /content/Control_fif/v58p.fif
# [done]
# Saved /content/Control_fif/v58p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v58p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16239
#     Range : 0 ... 16238 =      0.000 ...   126.859 secs
# Ready.
# Writing /content/Control_fif/v50p.fif
# Closing /content/Control_fif/v50p.fif
# [done]
# Saved /content/Control_fif/v50p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v50p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12929
#     Range : 0 ... 12928 =      0.000 ...   101.000 secs
# Ready.
# Writing /content/Control_fif/v60p.fif
# Closing /content/Control_fif/v60p.fif
# [done]
# Saved /content/Control_fif/v60p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v60p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=10871
#     Range : 0 ... 10870 =      0.000 ...    84.922 secs
# Ready.
# Writing /content/Control_fif/v45p.fif
# Closing /content/Control_fif/v45p.fif
# [done]
# Saved /content/Control_fif/v45p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v45p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13883
#     Range : 0 ... 13882 =      0.000 ...   108.453 secs
# Ready.
# Writing /content/Control_fif/v52p.fif
# Closing /content/Control_fif/v52p.fif
# [done]
# Saved /content/Control_fif/v52p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v52p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=9823
#     Range : 0 ... 9822 =      0.000 ...    76.734 secs
# Ready.
# Writing /content/Control_fif/v46p.fif
# Closing /content/Control_fif/v46p.fif
# [done]
# Saved /content/Control_fif/v46p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v46p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=10452
#     Range : 0 ... 10451 =      0.000 ...    81.648 secs
# Ready.
# Writing /content/Control_fif/v48p.fif
# Closing /content/Control_fif/v48p.fif
# [done]
# Saved /content/Control_fif/v48p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v48p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14139
#     Range : 0 ... 14138 =      0.000 ...   110.453 secs
# Ready.
# Writing /content/Control_fif/v56p.fif
# Closing /content/Control_fif/v56p.fif
# [done]
# Saved /content/Control_fif/v56p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v56p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19234
#     Range : 0 ... 19233 =      0.000 ...   150.258 secs
# Ready.
# Writing /content/Control_fif/v54p.fif
# Closing /content/Control_fif/v54p.fif
# [done]
# Saved /content/Control_fif/v54p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v54p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=10864
#     Range : 0 ... 10863 =      0.000 ...    84.867 secs
# Ready.
# Writing /content/Control_fif/v47p.fif
# Closing /content/Control_fif/v47p.fif
# [done]
# Saved /content/Control_fif/v47p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v47p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14282
#     Range : 0 ... 14281 =      0.000 ...   111.570 secs
# Ready.
# Writing /content/Control_fif/v55p.fif
# Closing /content/Control_fif/v55p.fif
# [done]
# Saved /content/Control_fif/v55p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v55p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19122
#     Range : 0 ... 19121 =      0.000 ...   149.383 secs
# Ready.
# Writing /content/Control_fif/v53p.fif
# Closing /content/Control_fif/v53p.fif
# [done]
# Saved /content/Control_fif/v53p.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v53p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=25659
#     Range : 0 ... 25658 =      0.000 ...   200.453 secs
# Ready.
# Writing /content/Control_fif/v117.fif
# Closing /content/Control_fif/v117.fif
# [done]
# Saved /content/Control_fif/v117.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v117.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14550
#     Range : 0 ... 14549 =      0.000 ...   113.664 secs
# Ready.
# Writing /content/Control_fif/v123.fif
# Closing /content/Control_fif/v123.fif
# [done]
# Saved /content/Control_fif/v123.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v123.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16686
#     Range : 0 ... 16685 =      0.000 ...   130.352 secs
# Ready.
# Writing /content/Control_fif/v131.fif
# Closing /content/Control_fif/v131.fif
# [done]
# Saved /content/Control_fif/v131.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v131.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14209
#     Range : 0 ... 14208 =      0.000 ...   111.000 secs
# Ready.
# Writing /content/Control_fif/v147.fif
# Closing /content/Control_fif/v147.fif
# [done]
# Saved /content/Control_fif/v147.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v147.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15378
#     Range : 0 ... 15377 =      0.000 ...   120.133 secs
# Ready.
# Writing /content/Control_fif/v125.fif
# Closing /content/Control_fif/v125.fif
# [done]
# Saved /content/Control_fif/v125.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v125.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12007
#     Range : 0 ... 12006 =      0.000 ...    93.797 secs
# Ready.
# Writing /content/Control_fif/v118.fif
# Closing /content/Control_fif/v118.fif
# [done]
# Saved /content/Control_fif/v118.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v118.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12033
#     Range : 0 ... 12032 =      0.000 ...    94.000 secs
# Ready.
# Writing /content/Control_fif/v120.fif
# Closing /content/Control_fif/v120.fif
# [done]
# Saved /content/Control_fif/v120.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v120.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14721
#     Range : 0 ... 14720 =      0.000 ...   115.000 secs
# Ready.
# Writing /content/Control_fif/v127.fif
# Closing /content/Control_fif/v127.fif
# [done]
# Saved /content/Control_fif/v127.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v127.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17098
#     Range : 0 ... 17097 =      0.000 ...   133.570 secs
# Ready.
# Writing /content/Control_fif/v149.fif
# Closing /content/Control_fif/v149.fif
# [done]
# Saved /content/Control_fif/v149.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v149.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=11208
#     Range : 0 ... 11207 =      0.000 ...    87.555 secs
# Ready.
# Writing /content/Control_fif/v129.fif
# Closing /content/Control_fif/v129.fif
# [done]
# Saved /content/Control_fif/v129.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v129.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13359
#     Range : 0 ... 13358 =      0.000 ...   104.359 secs
# Ready.
# Writing /content/Control_fif/v134.fif
# Closing /content/Control_fif/v134.fif
# [done]
# Saved /content/Control_fif/v134.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v134.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12488
#     Range : 0 ... 12487 =      0.000 ...    97.555 secs
# Ready.
# Writing /content/Control_fif/v138.fif
# Closing /content/Control_fif/v138.fif
# [done]
# Saved /content/Control_fif/v138.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v138.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16377
#     Range : 0 ... 16376 =      0.000 ...   127.938 secs
# Ready.
# Writing /content/Control_fif/v121.fif
# Closing /content/Control_fif/v121.fif
# [done]
# Saved /content/Control_fif/v121.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v121.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15607
#     Range : 0 ... 15606 =      0.000 ...   121.922 secs
# Ready.
# Writing /content/Control_fif/v143.fif
# Closing /content/Control_fif/v143.fif
# [done]
# Saved /content/Control_fif/v143.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v143.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15073
#     Range : 0 ... 15072 =      0.000 ...   117.750 secs
# Ready.
# Writing /content/Control_fif/v133.fif
# Closing /content/Control_fif/v133.fif
# [done]
# Saved /content/Control_fif/v133.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v133.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17187
#     Range : 0 ... 17186 =      0.000 ...   134.266 secs
# Ready.
# Writing /content/Control_fif/v140.fif
# Closing /content/Control_fif/v140.fif
# [done]
# Saved /content/Control_fif/v140.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v140.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17841
#     Range : 0 ... 17840 =      0.000 ...   139.375 secs
# Ready.
# Writing /content/Control_fif/v302.fif
# Closing /content/Control_fif/v302.fif
# [done]
# Saved /content/Control_fif/v302.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v302.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=22260
#     Range : 0 ... 22259 =      0.000 ...   173.898 secs
# Ready.
# Writing /content/Control_fif/v299.fif
# Closing /content/Control_fif/v299.fif
# [done]
# Saved /content/Control_fif/v299.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v299.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=25985
#     Range : 0 ... 25984 =      0.000 ...   203.000 secs
# Ready.
# Writing /content/Control_fif/v300.fif
# Closing /content/Control_fif/v300.fif
# [done]
# Saved /content/Control_fif/v300.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v300.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=20914
#     Range : 0 ... 20913 =      0.000 ...   163.383 secs
# Ready.
# Writing /content/Control_fif/v151.fif
# Closing /content/Control_fif/v151.fif
# [done]
# Saved /content/Control_fif/v151.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v151.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=24818
#     Range : 0 ... 24817 =      0.000 ...   193.883 secs
# Ready.
# Writing /content/Control_fif/v309.fif
# Closing /content/Control_fif/v309.fif
# [done]
# Saved /content/Control_fif/v309.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v309.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=22273
#     Range : 0 ... 22272 =      0.000 ...   174.000 secs
# Ready.
# Writing /content/Control_fif/v305.fif
# Closing /content/Control_fif/v305.fif
# [done]
# Saved /content/Control_fif/v305.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v305.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17025
#     Range : 0 ... 17024 =      0.000 ...   133.000 secs
# Ready.
# Writing /content/Control_fif/v308.fif
# Closing /content/Control_fif/v308.fif
# [done]
# Saved /content/Control_fif/v308.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v308.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13697
#     Range : 0 ... 13696 =      0.000 ...   107.000 secs
# Ready.
# Writing /content/Control_fif/v297.fif
# Closing /content/Control_fif/v297.fif
# [done]
# Saved /content/Control_fif/v297.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v297.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=22807
#     Range : 0 ... 22806 =      0.000 ...   178.172 secs
# Ready.
# Writing /content/Control_fif/v307.fif
# Closing /content/Control_fif/v307.fif
# [done]
# Saved /content/Control_fif/v307.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v307.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19222
#     Range : 0 ... 19221 =      0.000 ...   150.164 secs
# Ready.
# Writing /content/Control_fif/v303.fif
# Closing /content/Control_fif/v303.fif
# [done]
# Saved /content/Control_fif/v303.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v303.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17793
#     Range : 0 ... 17792 =      0.000 ...   139.000 secs
# Ready.
# Writing /content/Control_fif/v310.fif
# Closing /content/Control_fif/v310.fif
# [done]
# Saved /content/Control_fif/v310.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v310.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17782
#     Range : 0 ... 17781 =      0.000 ...   138.914 secs
# Ready.
# Writing /content/Control_fif/v298.fif
# Closing /content/Control_fif/v298.fif
# [done]
# Saved /content/Control_fif/v298.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v298.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13400
#     Range : 0 ... 13399 =      0.000 ...   104.680 secs
# Ready.
# Writing /content/Control_fif/v304.fif
# Closing /content/Control_fif/v304.fif
# [done]
# Saved /content/Control_fif/v304.fif
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v304.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18301
#     Range : 0 ... 18300 =      0.000 ...   142.969 secs
# Ready.
# Writing /content/Control_fif/v306.fif
# Closing /content/Control_fif/v306.fif
# [done]
# Saved /content/Control_fif/v306.fif
# Processing complete!
# <ipython-input-9-50440dbcbb57>:27: RuntimeWarning: This filename (/content/Control_fif/v306.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)

# %%
import os

folder_path = '/content/ADHD_fif'
for filename in os.listdir(folder_path):
    if filename.endswith('.fif'):
        # read .fif file
        file_path = os.path.join(folder_path, filename)
        raw = mne.io.read_raw_fif(file_path ,preload=True)

        l_freq = 0.5  # Cutoff frequency in Hz (e.g., remove slow drifts below 1 Hz)
        # Apply Cutoff frequency filter
        filtered_data=raw.filter(l_freq=l_freq, h_freq=None, fir_design='firwin', phase='zero')  # None for no high-frequency cutoff

        fnotch = 50  # Notch filter frequency (e.g., remove 50 Hz power line noise)
        # Apply notch filter
        filteredd_data = filtered_data.notch_filter(freqs=fnotch, picks=None, fir_design='firwin', phase='zero')

        #applying zero padding on the file
        n_zeros = 2
        zero_padding = np.zeros(n_zeros)
        data = filteredd_data.get_data()
        # Create a new array to hold the padded data
        padded_data = np.zeros((data.shape[0], data.shape[1] + 2 * n_zeros))

        # Iterate over each channel and apply zero-padding
        for ch_idx in range(data.shape[0]):
            channel_data = data[ch_idx]
            channel_padded = np.concatenate((zero_padding, channel_data, zero_padding))
            padded_data[ch_idx] = channel_padded

        # Create a new info object
        info = raw.info

        # Create a new RawArray object with the modified data
        raw_padded = mne.io.RawArray(padded_data, info)

        #applying moving avg filter
        # Iterate over each channel
        for i in range(len(raw_padded.ch_names)):
            # Get the data for the current channel
            data = raw_padded.get_data()[i]

            # Calculate the rolling mean
            moving_avg = pd.Series(data).rolling(window=5, min_periods=1).mean()

            # Replace NaNs in the rolling mean with zeros
            moving_avg = moving_avg.fillna(0)

            # Update the data in the Raw object with the rolling mean
            raw_padded._data[i] = moving_avg.values


        # Apply spatial filtering using Common Average Reference (CAR)
        raw_car = raw_padded.set_eeg_reference('average', projection=True)

        # Apply the projection to actually re-reference the data
        raw_car.apply_proj()


        # Save the modified Raw object back to the same file
        raw_car.save(file_path, overwrite=True)


print("Processing complete!")
# Out:
# Opening raw data file /content/ADHD_fif/v30p.fif...
# Isotrak not found
#     Range : 0 ... 21662 =      0.000 ...   169.234 secs
# Ready.
# Reading 0 ... 21662  =      0.000 ...   169.234 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v30p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=21667
#     Range : 0 ... 21666 =      0.000 ...   169.266 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v30p.fif
# Closing /content/ADHD_fif/v30p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v200.fif...
# Isotrak not found
#     Range : 0 ... 12738 =      0.000 ...    99.516 secs
# Ready.
# Reading 0 ... 12738  =      0.000 ...    99.516 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v30p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v200.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=12743
#     Range : 0 ... 12742 =      0.000 ...    99.547 secs
# Ready.
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v200.fif
# Closing /content/ADHD_fif/v200.fif
# [done]
# Opening raw data file /content/ADHD_fif/v33p.fif...
# Isotrak not found
#     Range : 0 ... 29216 =      0.000 ...   228.250 secs
# Ready.
# Reading 0 ... 29216  =      0.000 ...   228.250 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v200.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v33p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=29221
#     Range : 0 ... 29220 =      0.000 ...   228.281 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v33p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v33p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/ADHD_fif/v33p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v173.fif...
# Isotrak not found
#     Range : 0 ... 24240 =      0.000 ...   189.375 secs
# Ready.
# Reading 0 ... 24240  =      0.000 ...   189.375 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v173.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=24245
#     Range : 0 ... 24244 =      0.000 ...   189.406 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v173.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v173.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/ADHD_fif/v173.fif
# [done]
# Opening raw data file /content/ADHD_fif/v22p.fif...
# Isotrak not found
#     Range : 0 ... 12099 =      0.000 ...    94.523 secs
# Ready.
# Reading 0 ... 12099  =      0.000 ...    94.523 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v22p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=12104
#     Range : 0 ... 12103 =      0.000 ...    94.555 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v22p.fif
# Closing /content/ADHD_fif/v22p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v15p.fif...
# Isotrak not found
#     Range : 0 ... 43251 =      0.000 ...   337.898 secs
# Ready.
# Reading 0 ... 43251  =      0.000 ...   337.898 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v22p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v15p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=43256
#     Range : 0 ... 43255 =      0.000 ...   337.930 secs
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v15p.fif
# Closing /content/ADHD_fif/v15p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v246.fif...
# Isotrak not found
#     Range : 0 ... 21306 =      0.000 ...   166.453 secs
# Ready.
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v15p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v246.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Reading 0 ... 21306  =      0.000 ...   166.453 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=21311
#     Range : 0 ... 21310 =      0.000 ...   166.484 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v246.fif
# Closing /content/ADHD_fif/v246.fif
# [done]
# Opening raw data file /content/ADHD_fif/v18p.fif...
# Isotrak not found
#     Range : 0 ... 25002 =      0.000 ...   195.328 secs
# Ready.
# Reading 0 ... 25002  =      0.000 ...   195.328 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v246.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v18p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=25007
#     Range : 0 ... 25006 =      0.000 ...   195.359 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v18p.fif
# Closing /content/ADHD_fif/v18p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v27p.fif...
# Isotrak not found
#     Range : 0 ... 28879 =      0.000 ...   225.617 secs
# Ready.
# Reading 0 ... 28879  =      0.000 ...   225.617 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v18p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v27p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=28884
#     Range : 0 ... 28883 =      0.000 ...   225.648 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v27p.fif
# Closing /content/ADHD_fif/v27p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v21p.fif...
# Isotrak not found
#     Range : 0 ... 16573 =      0.000 ...   129.477 secs
# Ready.
# Reading 0 ... 16573  =      0.000 ...   129.477 secs...
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v27p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v21p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=16578
#     Range : 0 ... 16577 =      0.000 ...   129.508 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v21p.fif
# Closing /content/ADHD_fif/v21p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v10p.fif...
# Isotrak not found
#     Range : 0 ... 14303 =      0.000 ...   111.742 secs
# Ready.
# Reading 0 ... 14303  =      0.000 ...   111.742 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v21p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v10p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=14308
#     Range : 0 ... 14307 =      0.000 ...   111.773 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v10p.fif
# Closing /content/ADHD_fif/v10p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v34p.fif...
# Isotrak not found
#     Range : 0 ... 19554 =      0.000 ...   152.766 secs
# Ready.
# Reading 0 ... 19554  =      0.000 ...   152.766 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v10p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v34p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=19559
#     Range : 0 ... 19558 =      0.000 ...   152.797 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v34p.fif
# Closing /content/ADHD_fif/v34p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v3p.fif...
# Isotrak not found
#     Range : 0 ... 33569 =      0.000 ...   262.258 secs
# Ready.
# Reading 0 ... 33569  =      0.000 ...   262.258 secs...
# Filtering raw data in 1 contiguous segment
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v34p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v3p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=33574
#     Range : 0 ... 33573 =      0.000 ...   262.289 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v3p.fif
# Closing /content/ADHD_fif/v3p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v204.fif...
# Isotrak not found
#     Range : 0 ... 20455 =      0.000 ...   159.805 secs
# Ready.
# Reading 0 ... 20455  =      0.000 ...   159.805 secs...
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v3p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v204.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=20460
#     Range : 0 ... 20459 =      0.000 ...   159.836 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v204.fif
# Closing /content/ADHD_fif/v204.fif
# [done]
# Opening raw data file /content/ADHD_fif/v279.fif...
# Isotrak not found
#     Range : 0 ... 20133 =      0.000 ...   157.289 secs
# Ready.
# Reading 0 ... 20133  =      0.000 ...   157.289 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v204.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v279.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=20138
#     Range : 0 ... 20137 =      0.000 ...   157.320 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v279.fif
# Closing /content/ADHD_fif/v279.fif
# [done]
# Opening raw data file /content/ADHD_fif/v250.fif...
# Isotrak not found
#     Range : 0 ... 13852 =      0.000 ...   108.219 secs
# Ready.
# Reading 0 ... 13852  =      0.000 ...   108.219 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v279.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v250.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=13857
#     Range : 0 ... 13856 =      0.000 ...   108.250 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v250.fif
# Closing /content/ADHD_fif/v250.fif
# [done]
# Opening raw data file /content/ADHD_fif/v196.fif...
# Isotrak not found
#     Range : 0 ... 13394 =      0.000 ...   104.641 secs
# Ready.
# Reading 0 ... 13394  =      0.000 ...   104.641 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v250.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v196.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=13399
#     Range : 0 ... 13398 =      0.000 ...   104.672 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v196.fif
# Closing /content/ADHD_fif/v196.fif
# [done]
# Opening raw data file /content/ADHD_fif/v238.fif...
# Isotrak not found
#     Range : 0 ... 9851 =      0.000 ...    76.961 secs
# Ready.
# Reading 0 ... 9851  =      0.000 ...    76.961 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v196.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v238.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=9856
#     Range : 0 ... 9855 =      0.000 ...    76.992 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v238.fif
# Closing /content/ADHD_fif/v238.fif
# [done]
# Opening raw data file /content/ADHD_fif/v28p.fif...
# Isotrak not found
#     Range : 0 ... 27611 =      0.000 ...   215.711 secs
# Ready.
# Reading 0 ... 27611  =      0.000 ...   215.711 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v238.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# ...
#   raw_car.save(file_path, overwrite=True)
# Overwriting existing file.
# Writing /content/ADHD_fif/v209.fif
# Closing /content/ADHD_fif/v209.fif
# [done]
# Opening raw data file /content/ADHD_fif/v37p.fif...
# Isotrak not found
#     Range : 0 ... 9285 =      0.000 ...    72.539 secs
# Ready.
# Reading 0 ... 9285  =      0.000 ...    72.539 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=9290
#     Range : 0 ... 9289 =      0.000 ...    72.570 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v37p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v37p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Overwriting existing file.
# Writing /content/ADHD_fif/v37p.fif
# Closing /content/ADHD_fif/v37p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v6p.fif...
# Isotrak not found
#     Range : 0 ... 17560 =      0.000 ...   137.188 secs
# Ready.
# Reading 0 ... 17560  =      0.000 ...   137.188 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v6p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=17565
#     Range : 0 ... 17564 =      0.000 ...   137.219 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v6p.fif
# Closing /content/ADHD_fif/v6p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v274.fif...
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v6p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v274.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Isotrak not found
#     Range : 0 ... 17322 =      0.000 ...   135.328 secs
# Ready.
# Reading 0 ... 17322  =      0.000 ...   135.328 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=17327
#     Range : 0 ... 17326 =      0.000 ...   135.359 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v274.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v274.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/ADHD_fif/v274.fif
# [done]
# Opening raw data file /content/ADHD_fif/v14p.fif...
# Isotrak not found
#     Range : 0 ... 17561 =      0.000 ...   137.195 secs
# Ready.
# Reading 0 ... 17561  =      0.000 ...   137.195 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=17566
#     Range : 0 ... 17565 =      0.000 ...   137.227 secs
# Ready.
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v14p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v14p.fif
# Closing /content/ADHD_fif/v14p.fif
# [done]
# Opening raw data file /content/ADHD_fif/v206.fif...
# Isotrak not found
#     Range : 0 ... 20172 =      0.000 ...   157.594 secs
# Ready.
# Reading 0 ... 20172  =      0.000 ...   157.594 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v14p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v206.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=20177
#     Range : 0 ... 20176 =      0.000 ...   157.625 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v206.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v206.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/ADHD_fif/v206.fif
# [done]
# Opening raw data file /content/ADHD_fif/v25p.fif...
# Isotrak not found
#     Range : 0 ... 9893 =      0.000 ...    77.289 secs
# Ready.
# Reading 0 ... 9893  =      0.000 ...    77.289 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=9898
#     Range : 0 ... 9897 =      0.000 ...    77.320 secs
# Ready.
# <ipython-input-10-a703b0f755a1>:8: RuntimeWarning: This filename (/content/ADHD_fif/v25p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/ADHD_fif/v25p.fif
# Closing /content/ADHD_fif/v25p.fif
# [done]
# Processing complete!
# <ipython-input-10-a703b0f755a1>:61: RuntimeWarning: This filename (/content/ADHD_fif/v25p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)

# %%
folder_path = '/content/Control_fif'

for filename in os.listdir(folder_path):
    if filename.endswith('.fif'):
        # read .fif file
        file_path = os.path.join(folder_path, filename)
        raw = mne.io.read_raw_fif(file_path ,preload=True)

        l_freq = 0.5  # Cutoff frequency in Hz (e.g., remove slow drifts below 1 Hz)
        # Apply Cutoff frequency filter
        filtered_data=raw.filter(l_freq=l_freq, h_freq=None, fir_design='firwin', phase='zero')  # None for no high-frequency cutoff

        fnotch = 50  # Notch filter frequency (e.g., remove 50 Hz power line noise)
        # Apply notch filter
        filteredd_data = filtered_data.notch_filter(freqs=fnotch, picks=None, fir_design='firwin', phase='zero')

        #applying zero padding on the file
        n_zeros = 2
        zero_padding = np.zeros(n_zeros)
        data = filteredd_data.get_data()
        # Create a new array to hold the padded data
        padded_data = np.zeros((data.shape[0], data.shape[1] + 2 * n_zeros))

        # Iterate over each channel and apply zero-padding
        for ch_idx in range(data.shape[0]):
            channel_data = data[ch_idx]
            channel_padded = np.concatenate((zero_padding, channel_data, zero_padding))
            padded_data[ch_idx] = channel_padded

        # Create a new info object
        info = raw.info

        # Create a new RawArray object with the modified data
        raw_padded = mne.io.RawArray(padded_data, info)

        #applying moving avg filter
        # Iterate over each channel
        for i in range(len(raw_padded.ch_names)):
            # Get the data for the current channel
            data = raw_padded.get_data()[i]

            # Calculate the rolling mean
            moving_avg = pd.Series(data).rolling(window=5, min_periods=1).mean()

            # Replace NaNs in the rolling mean with zeros
            moving_avg = moving_avg.fillna(0)

            # Update the data in the Raw object with the rolling mean
            raw_padded._data[i] = moving_avg.values


        # Apply spatial filtering using Common Average Reference (CAR)
        raw_car = raw_padded.set_eeg_reference('average', projection=True)

        # Apply the projection to actually re-reference the data
        raw_car.apply_proj()


        # Save the modified Raw object back to the same file
        raw_car.save(file_path, overwrite=True)
print("Processing complete!")
# Out:
# Opening raw data file /content/Control_fif/v127.fif...
# Isotrak not found
#     Range : 0 ... 14720 =      0.000 ...   115.000 secs
# Ready.
# Reading 0 ... 14720  =      0.000 ...   115.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v127.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=14725
#     Range : 0 ... 14724 =      0.000 ...   115.031 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v127.fif
# Closing /content/Control_fif/v127.fif
# [done]
# Opening raw data file /content/Control_fif/v129.fif...
# Isotrak not found
#     Range : 0 ... 11207 =      0.000 ...    87.555 secs
# Ready.
# Reading 0 ... 11207  =      0.000 ...    87.555 secs...
# Filtering raw data in 1 contiguous segment
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v127.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v129.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=11212
#     Range : 0 ... 11211 =      0.000 ...    87.586 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v129.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Overwriting existing file.
# Writing /content/Control_fif/v129.fif
# Closing /content/Control_fif/v129.fif
# [done]
# Opening raw data file /content/Control_fif/v45p.fif...
# Isotrak not found
#     Range : 0 ... 10870 =      0.000 ...    84.922 secs
# Ready.
# Reading 0 ... 10870  =      0.000 ...    84.922 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v45p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=10875
#     Range : 0 ... 10874 =      0.000 ...    84.953 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v45p.fif
# Closing /content/Control_fif/v45p.fif
# [done]
# Opening raw data file /content/Control_fif/v118.fif...
# Isotrak not found
#     Range : 0 ... 12006 =      0.000 ...    93.797 secs
# Ready.
# Reading 0 ... 12006  =      0.000 ...    93.797 secs...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v45p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v118.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=12011
#     Range : 0 ... 12010 =      0.000 ...    93.828 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v118.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v118.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/Control_fif/v118.fif
# [done]
# Opening raw data file /content/Control_fif/v114.fif...
# Isotrak not found
#     Range : 0 ... 13303 =      0.000 ...   103.930 secs
# Ready.
# Reading 0 ... 13303  =      0.000 ...   103.930 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v114.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=13308
#     Range : 0 ... 13307 =      0.000 ...   103.961 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v114.fif
# Closing /content/Control_fif/v114.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v114.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# [done]
# Opening raw data file /content/Control_fif/v57p.fif...
# Isotrak not found
#     Range : 0 ... 14691 =      0.000 ...   114.773 secs
# Ready.
# Reading 0 ... 14691  =      0.000 ...   114.773 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v57p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=14696
#     Range : 0 ... 14695 =      0.000 ...   114.805 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v57p.fif
# Closing /content/Control_fif/v57p.fif
# [done]
# Opening raw data file /content/Control_fif/v107.fif...
# Isotrak not found
#     Range : 0 ... 19793 =      0.000 ...   154.633 secs
# Ready.
# Reading 0 ... 19793  =      0.000 ...   154.633 secs...
# Filtering raw data in 1 contiguous segment
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v57p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v107.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=19798
#     Range : 0 ... 19797 =      0.000 ...   154.664 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v107.fif
# Closing /content/Control_fif/v107.fif
# [done]
# Opening raw data file /content/Control_fif/v151.fif...
# Isotrak not found
#     Range : 0 ... 20913 =      0.000 ...   163.383 secs
# Ready.
# Reading 0 ... 20913  =      0.000 ...   163.383 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v107.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v151.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=20918
#     Range : 0 ... 20917 =      0.000 ...   163.414 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v151.fif
# Closing /content/Control_fif/v151.fif
# [done]
# Opening raw data file /content/Control_fif/v41p.fif...
# Isotrak not found
#     Range : 0 ... 12499 =      0.000 ...    97.648 secs
# Ready.
# Reading 0 ... 12499  =      0.000 ...    97.648 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v151.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v41p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=12504
#     Range : 0 ... 12503 =      0.000 ...    97.680 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v41p.fif
# Closing /content/Control_fif/v41p.fif
# [done]
# Opening raw data file /content/Control_fif/v147.fif...
# Isotrak not found
#     Range : 0 ... 14208 =      0.000 ...   111.000 secs
# Ready.
# Reading 0 ... 14208  =      0.000 ...   111.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v41p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v147.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=14213
#     Range : 0 ... 14212 =      0.000 ...   111.031 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v147.fif
# Closing /content/Control_fif/v147.fif
# [done]
# Opening raw data file /content/Control_fif/v117.fif...
# Isotrak not found
#     Range : 0 ... 25658 =      0.000 ...   200.453 secs
# Ready.
# Reading 0 ... 25658  =      0.000 ...   200.453 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v147.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v117.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=25663
#     Range : 0 ... 25662 =      0.000 ...   200.484 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v117.fif
# Closing /content/Control_fif/v117.fif
# [done]
# Opening raw data file /content/Control_fif/v113.fif...
# Isotrak not found
#     Range : 0 ... 15573 =      0.000 ...   121.664 secs
# Ready.
# Reading 0 ... 15573  =      0.000 ...   121.664 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v117.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v113.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=15578
#     Range : 0 ... 15577 =      0.000 ...   121.695 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v113.fif
# Closing /content/Control_fif/v113.fif
# [done]
# Opening raw data file /content/Control_fif/v51p.fif...
# Isotrak not found
#     Range : 0 ... 7982 =      0.000 ...    62.359 secs
# Ready.
# Reading 0 ... 7982  =      0.000 ...    62.359 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v113.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v51p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=7987
#     Range : 0 ... 7986 =      0.000 ...    62.391 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v51p.fif
# Closing /content/Control_fif/v51p.fif
# [done]
# Opening raw data file /content/Control_fif/v299.fif...
# Isotrak not found
#     Range : 0 ... 22259 =      0.000 ...   173.898 secs
# Ready.
# Reading 0 ... 22259  =      0.000 ...   173.898 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v51p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v299.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=22264
#     Range : 0 ... 22263 =      0.000 ...   173.930 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v299.fif
# Closing /content/Control_fif/v299.fif
# [done]
# Opening raw data file /content/Control_fif/v309.fif...
# Isotrak not found
#     Range : 0 ... 24817 =      0.000 ...   193.883 secs
# Ready.
# Reading 0 ... 24817  =      0.000 ...   193.883 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v299.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v309.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=24822
#     Range : 0 ... 24821 =      0.000 ...   193.914 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v309.fif
# Closing /content/Control_fif/v309.fif
# [done]
# Opening raw data file /content/Control_fif/v308.fif...
# Isotrak not found
#     Range : 0 ... 17024 =      0.000 ...   133.000 secs
# Ready.
# Reading 0 ... 17024  =      0.000 ...   133.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v309.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v308.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=17029
#     Range : 0 ... 17028 =      0.000 ...   133.031 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v308.fif
# Closing /content/Control_fif/v308.fif
# [done]
# Opening raw data file /content/Control_fif/v56p.fif...
# Isotrak not found
#     Range : 0 ... 14138 =      0.000 ...   110.453 secs
# Ready.
# Reading 0 ... 14138  =      0.000 ...   110.453 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v308.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v56p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=14143
#     Range : 0 ... 14142 =      0.000 ...   110.484 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v56p.fif
# Closing /content/Control_fif/v56p.fif
# [done]
# Opening raw data file /content/Control_fif/v305.fif...
# Isotrak not found
#     Range : 0 ... 22272 =      0.000 ...   174.000 secs
# Ready.
# Reading 0 ... 22272  =      0.000 ...   174.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v56p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v305.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=22277
#     Range : 0 ... 22276 =      0.000 ...   174.031 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v305.fif
# Closing /content/Control_fif/v305.fif
# [done]
# Opening raw data file /content/Control_fif/v115.fif...
# Isotrak not found
#     Range : 0 ... 15650 =      0.000 ...   122.266 secs
# Ready.
# Reading 0 ... 15650  =      0.000 ...   122.266 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# ...
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v306.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v46p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=9827
#     Range : 0 ... 9826 =      0.000 ...    76.766 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Overwriting existing file.
# Writing /content/Control_fif/v46p.fif
# Closing /content/Control_fif/v46p.fif
# [done]
# Opening raw data file /content/Control_fif/v302.fif...
# Isotrak not found
#     Range : 0 ... 17840 =      0.000 ...   139.375 secs
# Ready.
# Reading 0 ... 17840  =      0.000 ...   139.375 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v46p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v302.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=17845
#     Range : 0 ... 17844 =      0.000 ...   139.406 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v302.fif
# Closing /content/Control_fif/v302.fif
# [done]
# Opening raw data file /content/Control_fif/v307.fif...
# Isotrak not found
#     Range : 0 ... 22806 =      0.000 ...   178.172 secs
# Ready.
# Reading 0 ... 22806  =      0.000 ...   178.172 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v302.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v307.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=22811
#     Range : 0 ... 22810 =      0.000 ...   178.203 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v307.fif
# Closing /content/Control_fif/v307.fif
# [done]
# Opening raw data file /content/Control_fif/v125.fif...
# Isotrak not found
#     Range : 0 ... 15377 =      0.000 ...   120.133 secs
# Ready.
# Reading 0 ... 15377  =      0.000 ...   120.133 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v307.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v125.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=15382
#     Range : 0 ... 15381 =      0.000 ...   120.164 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v125.fif
# Closing /content/Control_fif/v125.fif
# [done]
# Opening raw data file /content/Control_fif/v138.fif...
# Isotrak not found
#     Range : 0 ... 12487 =      0.000 ...    97.555 secs
# Ready.
# Reading 0 ... 12487  =      0.000 ...    97.555 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v125.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v138.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=12492
#     Range : 0 ... 12491 =      0.000 ...    97.586 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v138.fif
# Closing /content/Control_fif/v138.fif
# [done]
# Opening raw data file /content/Control_fif/v120.fif...
# Isotrak not found
#     Range : 0 ... 12032 =      0.000 ...    94.000 secs
# Ready.
# Reading 0 ... 12032  =      0.000 ...    94.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v138.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-11-df9926a81a47>:7: RuntimeWarning: This filename (/content/Control_fif/v120.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=12037
#     Range : 0 ... 12036 =      0.000 ...    94.031 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/Control_fif/v120.fif
# Closing /content/Control_fif/v120.fif
# [done]
# Processing complete!
# <ipython-input-11-df9926a81a47>:60: RuntimeWarning: This filename (/content/Control_fif/v120.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)

# %%
#creating a list with the paths of the adhd files
ADHD_files_path = glob.glob(os.path.join('/content/ADHD_fif', '*.fif')) #path of the filtered data (adhd ones)
ADHD_files_path_50 = ADHD_files_path[:50]
print(len(ADHD_files_path_50))
# Out:
# 50

# %%
#creating a list with the paths of the control files
control_files_path=glob.glob(os.path.join(r'/content/Control_fif/','*.fif')) #path of the filtered data (normal ones)
print(len(control_files_path))
# Out:
# 60

# %%
def read_data(file_path):
    datax=mne.io.read_raw_fif(file_path,preload=True)
    epochs=mne.make_fixed_length_epochs(datax,duration=10,overlap=0.75)
    epochs=epochs.get_data() #turning the epochs to arrays
    return epochs

# %%
NON_ADHD_epochs_array=[read_data(subject) for subject in control_files_path]
ADHD_epochs_array=[read_data(subject) for subject in ADHD_files_path_50]
# Out:
# Opening raw data file /content/Control_fif/v127.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 14724 =      0.000 ...   115.031 secs
# Ready.
# Reading 0 ... 14724  =      0.000 ...   115.031 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v129.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 11211 =      0.000 ...    87.586 secs
# Ready.
# Reading 0 ... 11211  =      0.000 ...    87.586 secs...
# Not setting metadata
# 9 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 9 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v45p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 10874 =      0.000 ...    84.953 secs
# Ready.
# Reading 0 ... 10874  =      0.000 ...    84.953 secs...
# Not setting metadata
# 9 matching events found
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v127.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v129.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v45p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 9 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v118.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12010 =      0.000 ...    93.828 secs
# Ready.
# Reading 0 ... 12010  =      0.000 ...    93.828 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v114.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13307 =      0.000 ...   103.961 secs
# Ready.
# Reading 0 ... 13307  =      0.000 ...   103.961 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v118.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v114.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v57p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 14695 =      0.000 ...   114.805 secs
# Ready.
# Reading 0 ... 14695  =      0.000 ...   114.805 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v107.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19797 =      0.000 ...   154.664 secs
# Ready.
# Reading 0 ... 19797  =      0.000 ...   154.664 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v151.fif...
# Isotrak not found
#     Read a total of 1 projection items:
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v57p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v107.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v151.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 20917 =      0.000 ...   163.414 secs
# Ready.
# Reading 0 ... 20917  =      0.000 ...   163.414 secs...
# Not setting metadata
# 17 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 17 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v41p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12503 =      0.000 ...    97.680 secs
# Ready.
# Reading 0 ... 12503  =      0.000 ...    97.680 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v147.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 14212 =      0.000 ...   111.031 secs
# Ready.
# Reading 0 ... 14212  =      0.000 ...   111.031 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v41p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v147.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v117.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 25662 =      0.000 ...   200.484 secs
# Ready.
# Reading 0 ... 25662  =      0.000 ...   200.484 secs...
# Not setting metadata
# 21 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 21 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v113.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15577 =      0.000 ...   121.695 secs
# Ready.
# Reading 0 ... 15577  =      0.000 ...   121.695 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v117.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v113.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v51p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 7986 =      0.000 ...    62.391 secs
# Ready.
# Reading 0 ... 7986  =      0.000 ...    62.391 secs...
# Not setting metadata
# 6 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 6 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v299.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 22263 =      0.000 ...   173.930 secs
# Ready.
# Reading 0 ... 22263  =      0.000 ...   173.930 secs...
# Not setting metadata
# 18 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v51p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v299.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Using data from preloaded Raw for 18 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v309.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 24821 =      0.000 ...   193.914 secs
# Ready.
# Reading 0 ... 24821  =      0.000 ...   193.914 secs...
# Not setting metadata
# 20 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 20 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v308.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 17028 =      0.000 ...   133.031 secs
# Ready.
# Reading 0 ... 17028  =      0.000 ...   133.031 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v309.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v308.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v56p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 14142 =      0.000 ...   110.484 secs
# Ready.
# Reading 0 ... 14142  =      0.000 ...   110.484 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v305.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 22276 =      0.000 ...   174.031 secs
# Ready.
# Reading 0 ... 22276  =      0.000 ...   174.031 secs...
# Not setting metadata
# 18 matching events found
# No baseline correction applied
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v56p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v305.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 18 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v115.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15654 =      0.000 ...   122.297 secs
# Ready.
# Reading 0 ... 15654  =      0.000 ...   122.297 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v60p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12932 =      0.000 ...   101.031 secs
# Ready.
# Reading 0 ... 12932  =      0.000 ...   101.031 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v300.fif...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v115.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v60p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v300.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 25988 =      0.000 ...   203.031 secs
# Ready.
# Reading 0 ... 25988  =      0.000 ...   203.031 secs...
# Not setting metadata
# 21 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 21 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v44p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 11396 =      0.000 ...    89.031 secs
# Ready.
# Reading 0 ... 11396  =      0.000 ...    89.031 secs...
# Not setting metadata
# 9 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 9 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v310.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 17796 =      0.000 ...   139.031 secs
# Ready.
# Reading 0 ... 17796  =      0.000 ...   139.031 secs...
# Not setting metadata
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v44p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v310.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v50p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16242 =      0.000 ...   126.891 secs
# Ready.
# Reading 0 ... 16242  =      0.000 ...   126.891 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v47p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 10867 =      0.000 ...    84.898 secs
# Ready.
# Reading 0 ... 10867  =      0.000 ...    84.898 secs...
# Not setting metadata
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v50p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v47p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 9 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 9 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v133.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15076 =      0.000 ...   117.781 secs
# Ready.
# Reading 0 ... 15076  =      0.000 ...   117.781 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v298.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 17785 =      0.000 ...   138.945 secs
# Ready.
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v133.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v298.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Reading 0 ... 17785  =      0.000 ...   138.945 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v134.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13362 =      0.000 ...   104.391 secs
# Ready.
# Reading 0 ... 13362  =      0.000 ...   104.391 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v134.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v140.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 17190 =      0.000 ...   134.297 secs
# Ready.
# Reading 0 ... 17190  =      0.000 ...   134.297 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v140.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v53p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19125 =      0.000 ...   149.414 secs
# Ready.
# Reading 0 ... 19125  =      0.000 ...   149.414 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v53p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v52p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13886 =      0.000 ...   108.484 secs
# Ready.
# Reading 0 ... 13886  =      0.000 ...   108.484 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v52p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v49p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16772 =      0.000 ...   131.031 secs
# Ready.
# Reading 0 ... 16772  =      0.000 ...   131.031 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v49p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v108.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19029 =      0.000 ...   148.664 secs
# Ready.
# Reading 0 ... 19029  =      0.000 ...   148.664 secs...
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 15 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v108.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v112.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15946 =      0.000 ...   124.578 secs
# Ready.
# Reading 0 ... 15946  =      0.000 ...   124.578 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v121.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16380 =      0.000 ...   127.969 secs
# Ready.
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v112.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v121.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Reading 0 ... 16380  =      0.000 ...   127.969 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v143.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15610 =      0.000 ...   121.953 secs
# Ready.
# Reading 0 ... 15610  =      0.000 ...   121.953 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v143.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v59p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16516 =      0.000 ...   129.031 secs
# Ready.
# Reading 0 ... 16516  =      0.000 ...   129.031 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v131.fif...
# Isotrak not found
#     Read a total of 1 projection items:
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v59p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v131.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16689 =      0.000 ...   130.383 secs
# Ready.
# Reading 0 ... 16689  =      0.000 ...   130.383 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v111.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15313 =      0.000 ...   119.633 secs
# Ready.
# Reading 0 ... 15313  =      0.000 ...   119.633 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v109.fif...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v111.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v109.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16047 =      0.000 ...   125.367 secs
# Ready.
# Reading 0 ... 16047  =      0.000 ...   125.367 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v43p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12753 =      0.000 ...    99.633 secs
# Ready.
# Reading 0 ... 12753  =      0.000 ...    99.633 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v55p.fif...
# Isotrak not found
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v43p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v55p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 14285 =      0.000 ...   111.602 secs
# Ready.
# Reading 0 ... 14285  =      0.000 ...   111.602 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v110.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16552 =      0.000 ...   129.312 secs
# Ready.
# Reading 0 ... 16552  =      0.000 ...   129.312 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v297.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13700 =      0.000 ...   107.031 secs
# Ready.
# Reading 0 ... 13700  =      0.000 ...   107.031 secs...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v110.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v297.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v58p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13921 =      0.000 ...   108.758 secs
# Ready.
# Reading 0 ... 13921  =      0.000 ...   108.758 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v42p.fif...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v58p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v42p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16707 =      0.000 ...   130.523 secs
# Ready.
# Reading 0 ... 16707  =      0.000 ...   130.523 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v123.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 14553 =      0.000 ...   113.695 secs
# Ready.
# Reading 0 ... 14553  =      0.000 ...   113.695 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v123.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v48p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 10455 =      0.000 ...    81.680 secs
# Ready.
# Reading 0 ... 10455  =      0.000 ...    81.680 secs...
# Not setting metadata
# 8 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 8 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v54p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19237 =      0.000 ...   150.289 secs
# Ready.
# Reading 0 ... 19237  =      0.000 ...   150.289 secs...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v48p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v54p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v303.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19225 =      0.000 ...   150.195 secs
# Ready.
# Reading 0 ... 19225  =      0.000 ...   150.195 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v149.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 17101 =      0.000 ...   133.602 secs
# Ready.
# Reading 0 ... 17101  =      0.000 ...   133.602 secs...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v303.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v149.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v116.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19304 =      0.000 ...   150.812 secs
# Ready.
# Reading 0 ... 19304  =      0.000 ...   150.812 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/Control_fif/v304.fif...
# Isotrak not found
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v116.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/Control_fif/v304.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13403 =      0.000 ...   104.711 secs
# Ready.
# Reading 0 ... 13403  =      0.000 ...   104.711 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# ...
# Not setting metadata
# 28 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 28 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v234.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v179.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12676 =      0.000 ...    99.031 secs
# Ready.
# Reading 0 ... 12676  =      0.000 ...    99.031 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v12p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 17607 =      0.000 ...   137.555 secs
# Ready.
# Reading 0 ... 17607  =      0.000 ...   137.555 secs...
# Not setting metadata
# 14 matching events found
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v179.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v12p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v32p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 18052 =      0.000 ...   141.031 secs
# Ready.
# Reading 0 ... 18052  =      0.000 ...   141.031 secs...
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 15 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v32p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v263.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 18660 =      0.000 ...   145.781 secs
# Ready.
# Reading 0 ... 18660  =      0.000 ...   145.781 secs...
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 15 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v231.fif...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v263.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v231.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19716 =      0.000 ...   154.031 secs
# Ready.
# Reading 0 ... 19716  =      0.000 ...   154.031 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v29p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 24196 =      0.000 ...   189.031 secs
# Ready.
# Reading 0 ... 24196  =      0.000 ...   189.031 secs...
# Not setting metadata
# 20 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 20 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v29p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v24p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16388 =      0.000 ...   128.031 secs
# Ready.
# Reading 0 ... 16388  =      0.000 ...   128.031 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v19p.fif...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v24p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v19p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 23066 =      0.000 ...   180.203 secs
# Ready.
# Reading 0 ... 23066  =      0.000 ...   180.203 secs...
# Not setting metadata
# 19 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 19 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v219.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 27160 =      0.000 ...   212.188 secs
# Ready.
# Reading 0 ... 27160  =      0.000 ...   212.188 secs...
# Not setting metadata
# 22 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 22 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v215.fif...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v219.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v215.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 21375 =      0.000 ...   166.992 secs
# Ready.
# Reading 0 ... 21375  =      0.000 ...   166.992 secs...
# Not setting metadata
# 17 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 17 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v198.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19624 =      0.000 ...   153.312 secs
# Ready.
# Reading 0 ... 19624  =      0.000 ...   153.312 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v35p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15308 =      0.000 ...   119.594 secs
# Ready.
# Reading 0 ... 15308  =      0.000 ...   119.594 secs...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v198.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v35p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v190.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15468 =      0.000 ...   120.844 secs
# Ready.
# Reading 0 ... 15468  =      0.000 ...   120.844 secs...
# Not setting metadata
# 12 matching events found
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v190.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v40p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 20100 =      0.000 ...   157.031 secs
# Ready.
# Reading 0 ... 20100  =      0.000 ...   157.031 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v40p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v1p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12261 =      0.000 ...    95.789 secs
# Ready.
# Reading 0 ... 12261  =      0.000 ...    95.789 secs...
# Not setting metadata
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v1p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v8p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15779 =      0.000 ...   123.273 secs
# Ready.
# Reading 0 ... 15779  =      0.000 ...   123.273 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v8p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/ADHD_fif/v181.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 10671 =      0.000 ...    83.367 secs
# Ready.
# Reading 0 ... 10671  =      0.000 ...    83.367 secs...
# Not setting metadata
# 8 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 8 events and 1280 original time points ...
# <ipython-input-26-89f995403612>:2: RuntimeWarning: This filename (/content/ADHD_fif/v181.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped

# %%
#crating target values for each data
NON_ADHD_epochs_labels=[len(i)*[0] for i in NON_ADHD_epochs_array]
ADHD_epochs_labels=[len(i)*[1] for i in ADHD_epochs_array]
print(len(NON_ADHD_epochs_labels),len(ADHD_epochs_labels))
# Out:
# 60 50

# %%
#adding data of both adhd with control in one array
data_list=NON_ADHD_epochs_array+ADHD_epochs_array
#adding the target values of both adhd and control with eachother
label_list=NON_ADHD_epochs_labels+ADHD_epochs_labels
print(len(data_list),len(label_list))
# Out:
# 110 110

# %%
#stacking the values beside eachother
data_array=np.vstack(data_list)
label_array=np.hstack(label_list)
data_array=np.moveaxis(data_array,1,2)

print(data_array.shape,label_array.shape)
# Out:
# (1565, 1280, 19) (1565,)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv1D, BatchNormalization, LeakyReLU, MaxPool1D, GlobalAveragePooling1D, Dense, Dropout, AveragePooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.backend import clear_session
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras import Sequential, layers

model = Sequential([
        layers.Conv1D(filters=8, kernel_size=3, strides=1, input_shape=(1280, 19)), # 1
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        layers.MaxPool1D(pool_size=2, strides=2), # 2
        layers.Conv1D(filters=16, kernel_size=3, strides=1), # 3
        layers.LeakyReLU(),
        layers.MaxPool1D(pool_size=2, strides=2), # 4
        layers.Dropout(0.5),
        layers.Conv1D(filters=32, kernel_size=3, strides=1), # 5
        layers.LeakyReLU(),
        layers.AveragePooling1D(pool_size=2, strides=2), # 6
        layers.Dropout(0.5),
        layers.Conv1D(filters=64, kernel_size=3, strides=1), # 7
        layers.LeakyReLU(),
        layers.AveragePooling1D(pool_size=2, strides=2), # 8
        layers.Conv1D(filters=128, kernel_size=3, strides=1), # 9
        layers.LeakyReLU(),
        layers.AveragePooling1D(pool_size=2, strides=2), # 10
        layers.Conv1D(filters=256, kernel_size=3, strides=1), # 11
        layers.LeakyReLU(),
        layers.GlobalAveragePooling1D(), # 12
        layers.Dense(128), # 13
        layers.LeakyReLU(),
        layers.Dense(64), # 14
        layers.LeakyReLU(),
        layers.Dense(1, activation='sigmoid') # 15
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_51 (Conv1D)          (None, 1278, 8)           464
#
#  batch_normalization_10 (Ba  (None, 1278, 8)           32
#  tchNormalization)
#
#  leaky_re_lu_68 (LeakyReLU)  (None, 1278, 8)           0
#
#  max_pooling1d_20 (MaxPooli  (None, 639, 8)            0
#  ng1D)
#
#  conv1d_52 (Conv1D)          (None, 637, 16)           400
#
#  leaky_re_lu_69 (LeakyReLU)  (None, 637, 16)           0
#
#  max_pooling1d_21 (MaxPooli  (None, 318, 16)           0
#  ng1D)
#
#  dropout_17 (Dropout)        (None, 318, 16)           0
#
#  conv1d_53 (Conv1D)          (None, 316, 32)           1568
#
#  leaky_re_lu_70 (LeakyReLU)  (None, 316, 32)           0
#
#  average_pooling1d_21 (Aver  (None, 158, 32)           0
#  agePooling1D)
#
#  dropout_18 (Dropout)        (None, 158, 32)           0
#
#  conv1d_54 (Conv1D)          (None, 156, 64)           6208
#
#  leaky_re_lu_71 (LeakyReLU)  (None, 156, 64)           0
#
#  average_pooling1d_22 (Aver  (None, 78, 64)            0
#  agePooling1D)
#
#  conv1d_55 (Conv1D)          (None, 76, 128)           24704
#
#  leaky_re_lu_72 (LeakyReLU)  (None, 76, 128)           0
#
#  average_pooling1d_23 (Aver  (None, 38, 128)           0
#  agePooling1D)
#
#  conv1d_56 (Conv1D)          (None, 36, 256)           98560
#
#  leaky_re_lu_73 (LeakyReLU)  (None, 36, 256)           0
#
#  global_average_pooling1d_1  (None, 256)               0
#  0 (GlobalAveragePooling1D)
#
#  dense_27 (Dense)            (None, 128)               32896
#
#  leaky_re_lu_74 (LeakyReLU)  (None, 128)               0
#
#  dense_28 (Dense)            (None, 64)                8256
#
#  leaky_re_lu_75 (LeakyReLU)  (None, 64)                0
#
#  dense_29 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 173153 (676.38 KB)
# Trainable params: 173137 (676.32 KB)
# Non-trainable params: 16 (64.00 Byte)
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split dataset into train, validation, and test sets
train_features, test_val_features, train_labels, test_val_labels = train_test_split(data_array, label_array, test_size=0.2, random_state=42)
val_features, test_features, val_labels, test_labels = train_test_split(test_val_features, test_val_labels, test_size=0.5, random_state=42)

# Standardize features
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features.reshape(-1, train_features.shape[-1])).reshape(train_features.shape)
val_features = scaler.transform(val_features.reshape(-1, val_features.shape[-1])).reshape(val_features.shape)
test_features = scaler.transform(test_features.reshape(-1, test_features.shape[-1])).reshape(test_features.shape)

# %%
model.fit(train_features, train_labels, epochs=30, batch_size=100, validation_data=(val_features, val_labels))
# Out:
# Epoch 1/30
# 13/13 [==============================] - 8s 409ms/step - loss: 0.6992 - accuracy: 0.5064 - val_loss: 0.6881 - val_accuracy: 0.4872
# Epoch 2/30
# 13/13 [==============================] - 4s 283ms/step - loss: 0.6898 - accuracy: 0.5064 - val_loss: 0.6805 - val_accuracy: 0.6026
# Epoch 3/30
# 13/13 [==============================] - 4s 285ms/step - loss: 0.6852 - accuracy: 0.5487 - val_loss: 0.6540 - val_accuracy: 0.6026
# Epoch 4/30
# 13/13 [==============================] - 5s 359ms/step - loss: 0.6818 - accuracy: 0.5519 - val_loss: 0.6517 - val_accuracy: 0.5833
# Epoch 5/30
# 13/13 [==============================] - 5s 376ms/step - loss: 0.6652 - accuracy: 0.5863 - val_loss: 0.6323 - val_accuracy: 0.5962
# Epoch 6/30
# 13/13 [==============================] - 4s 295ms/step - loss: 0.6547 - accuracy: 0.6078 - val_loss: 0.5983 - val_accuracy: 0.6346
# Epoch 7/30
# 13/13 [==============================] - 4s 338ms/step - loss: 0.6341 - accuracy: 0.6398 - val_loss: 0.6042 - val_accuracy: 0.6795
# Epoch 8/30
# 13/13 [==============================] - 4s 301ms/step - loss: 0.5952 - accuracy: 0.6957 - val_loss: 0.5391 - val_accuracy: 0.6987
# Epoch 9/30
# 13/13 [==============================] - 3s 240ms/step - loss: 0.6060 - accuracy: 0.6973 - val_loss: 0.6181 - val_accuracy: 0.6410
# Epoch 10/30
# 13/13 [==============================] - 2s 181ms/step - loss: 0.5990 - accuracy: 0.6917 - val_loss: 0.5272 - val_accuracy: 0.7372
# Epoch 11/30
# 13/13 [==============================] - 2s 178ms/step - loss: 0.5525 - accuracy: 0.7388 - val_loss: 0.5694 - val_accuracy: 0.7051
# Epoch 12/30
# 13/13 [==============================] - 2s 182ms/step - loss: 0.5482 - accuracy: 0.7204 - val_loss: 0.5210 - val_accuracy: 0.7372
# Epoch 13/30
# 13/13 [==============================] - 3s 203ms/step - loss: 0.5303 - accuracy: 0.7476 - val_loss: 0.5028 - val_accuracy: 0.7436
# Epoch 14/30
# 13/13 [==============================] - 4s 308ms/step - loss: 0.5017 - accuracy: 0.7708 - val_loss: 0.4990 - val_accuracy: 0.7628
# Epoch 15/30
# 13/13 [==============================] - 3s 187ms/step - loss: 0.4966 - accuracy: 0.7732 - val_loss: 0.4745 - val_accuracy: 0.7628
# Epoch 16/30
# 13/13 [==============================] - 2s 189ms/step - loss: 0.4895 - accuracy: 0.7732 - val_loss: 0.4617 - val_accuracy: 0.7949
# Epoch 17/30
# 13/13 [==============================] - 2s 181ms/step - loss: 0.4845 - accuracy: 0.7780 - val_loss: 0.4513 - val_accuracy: 0.7949
# Epoch 18/30
# 13/13 [==============================] - 2s 180ms/step - loss: 0.4719 - accuracy: 0.7923 - val_loss: 0.4571 - val_accuracy: 0.7949
# Epoch 19/30
# 13/13 [==============================] - 4s 281ms/step - loss: 0.4657 - accuracy: 0.7987 - val_loss: 0.4867 - val_accuracy: 0.7308
# Epoch 20/30
# 13/13 [==============================] - 3s 267ms/step - loss: 0.4686 - accuracy: 0.7859 - val_loss: 0.4316 - val_accuracy: 0.8141
# Epoch 21/30
# 13/13 [==============================] - 2s 180ms/step - loss: 0.4417 - accuracy: 0.7955 - val_loss: 0.4294 - val_accuracy: 0.8141
# Epoch 22/30
# 13/13 [==============================] - 2s 181ms/step - loss: 0.4470 - accuracy: 0.7995 - val_loss: 0.5012 - val_accuracy: 0.7821
# Epoch 23/30
# 13/13 [==============================] - 2s 186ms/step - loss: 0.4106 - accuracy: 0.8195 - val_loss: 0.3949 - val_accuracy: 0.8269
# Epoch 24/30
# 13/13 [==============================] - 3s 194ms/step - loss: 0.4099 - accuracy: 0.8131 - val_loss: 0.3954 - val_accuracy: 0.8333
# Epoch 25/30
# 13/13 [==============================] - 4s 307ms/step - loss: 0.4384 - accuracy: 0.7947 - val_loss: 0.4373 - val_accuracy: 0.8205
# Epoch 26/30
# 13/13 [==============================] - 3s 228ms/step - loss: 0.3893 - accuracy: 0.8211 - val_loss: 0.3835 - val_accuracy: 0.8397
# Epoch 27/30
# 13/13 [==============================] - 2s 181ms/step - loss: 0.4131 - accuracy: 0.8211 - val_loss: 0.3973 - val_accuracy: 0.8333
# Epoch 28/30
# 13/13 [==============================] - 2s 193ms/step - loss: 0.3874 - accuracy: 0.8267 - val_loss: 0.4655 - val_accuracy: 0.8013
# Epoch 29/30
# 13/13 [==============================] - 2s 181ms/step - loss: 0.3411 - accuracy: 0.8514 - val_loss: 0.4030 - val_accuracy: 0.8590
# Epoch 30/30
# 13/13 [==============================] - 3s 245ms/step - loss: 0.3761 - accuracy: 0.8315 - val_loss: 0.3914 - val_accuracy: 0.8462

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
# Make predictions on test set
predictions = model.predict(test_features)
binary_predictions = np.round(predictions).flatten()

# Calculate confusion matrix
cm = confusion_matrix(test_labels, binary_predictions)

# Plot confusion matrix
labels = ['Normal', 'adhd']
display_labels = [label for label in labels]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.show()

accuracy=[]
# Calculate accuracy
accuracy.append(model.evaluate(test_features, test_labels)[1])
# Out:
# 5/5 [==============================] - 0s 19ms/step
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3965 - accuracy: 0.8153

# %%
#calculating sensitivity and specificity
tn, fp, fn, tp = cm.ravel()

sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
print(f"Sensitivity: {sensitivity}")
print(f"Specificity: {specificity}")
# Out:
# Sensitivity: 0.7349397590361446
# Specificity: 0.9054054054054054

# %%
from sklearn.metrics import classification_report

# Calculate precision, recall, F1-score
import numpy as np

# Calculate precision
precision = tp / (tp + fp) if (tp + fp) != 0 else 0

# Calculate recall
recall = tp / (tp + fn) if (tp + fn) != 0 else 0

# Calculate F-score
if precision + recall == 0:
    f_score = 0
else:
    f_score = 2 * (precision * recall) / (precision + recall)


print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F-score: {f_score}")
# Out:
# Precision: 0.8970588235294118
# Recall: 0.7349397590361446
# F-score: 0.8079470198675497

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve and ROC area for each class
fpr, tpr, _ = roc_curve(test_labels,predictions)

# Calculate area under the curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
